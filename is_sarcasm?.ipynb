# %% [markdown]
# <a href="https://colab.research.google.com/github/rezamohammadloo/is-sarcasm-/blob/main/is_sarcasm%3F.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Download the dataset
# !wget https://storage.googleapis.com/tensorflow-1-public/course3/sarcasm.json
# Out:
# --2023-12-27 07:34:59--  https://storage.googleapis.com/tensorflow-1-public/course3/sarcasm.json
# Resolving storage.googleapis.com (storage.googleapis.com)... 142.250.101.207, 142.251.2.207, 74.125.137.207, ...
# Connecting to storage.googleapis.com (storage.googleapis.com)|142.250.101.207|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 5643545 (5.4M) [application/json]
# Saving to: ‘sarcasm.json’
#
# sarcasm.json        100%[===================>]   5.38M  --.-KB/s    in 0.1s
#
# 2023-12-27 07:35:00 (54.4 MB/s) - ‘sarcasm.json’ saved [5643545/5643545]

# %%
import json

# Load the JSON file
with open("./sarcasm.json", 'r') as f:
    datastore = json.load(f)

# Initialize the lists
sentences = []
labels = []

# Collect sentences and labels into the lists
for item in datastore:
    sentences.append(item['headline'])
    labels.append(item['is_sarcastic'])

# %%
# Number of examples to use for training
training_size = 20000

# Vocabulary size of the tokenizer
vocab_size = 10000

# Maximum length of the padded sequences
max_length = 32

# Output dimensions of the Embedding layer
embedding_dim = 16

# %%
# Split the sentences
training_sentences = sentences[0:training_size]
testing_sentences = sentences[training_size:]

# Split the labels
training_labels = labels[0:training_size]
testing_labels = labels[training_size:]

# %%
print(len(training_labels))
print(len(testing_labels))
# Out:
# 6709

# %%
import numpy as np
from tensorflow.keras.preprocessing.text import Tokenizer
from tensorflow.keras.preprocessing.sequence import pad_sequences

# Parameters for padding and OOV tokens
trunc_type='post'
padding_type='post'
oov_tok = "<OOV>"

# Initialize the Tokenizer class
tokenizer = Tokenizer(num_words=vocab_size, oov_token=oov_tok)

# Generate the word index dictionary
tokenizer.fit_on_texts(training_sentences)
word_index = tokenizer.word_index

# Generate and pad the training sequences
training_sequences = tokenizer.texts_to_sequences(training_sentences)
training_padded = pad_sequences(training_sequences, maxlen=max_length, padding=padding_type, truncating=trunc_type)

# Generate and pad the testing sequences
testing_sequences = tokenizer.texts_to_sequences(testing_sentences)
testing_padded = pad_sequences(testing_sequences, maxlen=max_length, padding=padding_type, truncating=trunc_type)

# Convert the labels lists into numpy arrays
training_labels = np.array(training_labels)
testing_labels = np.array(testing_labels)

# %%
# Build the model
import tensorflow as tf
model = tf.keras.Sequential([
    tf.keras.layers.Embedding(vocab_size, embedding_dim, input_length=max_length),
    tf.keras.layers.GlobalAveragePooling1D(),
    tf.keras.layers.Dense(24, activation='relu'),
    tf.keras.layers.Dense(1, activation='sigmoid')
])

# Print the model summary
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  embedding (Embedding)       (None, 32, 16)            160000
#
#  global_average_pooling1d (  (None, 16)                0
#  GlobalAveragePooling1D)
#
#  dense (Dense)               (None, 24)                408
#
#  dense_1 (Dense)             (None, 1)                 25
#
# =================================================================
# Total params: 160433 (626.69 KB)
# Trainable params: 160433 (626.69 KB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________

# %%
# Compile the model
model.compile(loss='binary_crossentropy',optimizer='adam',metrics=['accuracy'])

# %%
num_epochs = 30

# Train the model
history = model.fit(training_padded, training_labels, epochs=num_epochs, validation_data=(testing_padded, testing_labels), verbose=2)
# Out:
# Epoch 1/30
# 625/625 - 5s - loss: 0.5817 - accuracy: 0.6848 - val_loss: 0.4103 - val_accuracy: 0.8264 - 5s/epoch - 8ms/step
# Epoch 2/30
# 625/625 - 3s - loss: 0.3184 - accuracy: 0.8715 - val_loss: 0.3426 - val_accuracy: 0.8553 - 3s/epoch - 4ms/step
# Epoch 3/30
# 625/625 - 3s - loss: 0.2386 - accuracy: 0.9061 - val_loss: 0.3518 - val_accuracy: 0.8508 - 3s/epoch - 4ms/step
# Epoch 4/30
# 625/625 - 3s - loss: 0.1932 - accuracy: 0.9270 - val_loss: 0.3552 - val_accuracy: 0.8526 - 3s/epoch - 4ms/step
# Epoch 5/30
# 625/625 - 4s - loss: 0.1618 - accuracy: 0.9406 - val_loss: 0.3799 - val_accuracy: 0.8518 - 4s/epoch - 6ms/step
# Epoch 6/30
# 625/625 - 3s - loss: 0.1362 - accuracy: 0.9513 - val_loss: 0.4155 - val_accuracy: 0.8486 - 3s/epoch - 4ms/step
# Epoch 7/30
# 625/625 - 3s - loss: 0.1166 - accuracy: 0.9607 - val_loss: 0.4453 - val_accuracy: 0.8459 - 3s/epoch - 4ms/step
# Epoch 8/30
# 625/625 - 3s - loss: 0.1006 - accuracy: 0.9669 - val_loss: 0.4913 - val_accuracy: 0.8405 - 3s/epoch - 4ms/step
# Epoch 9/30
# 625/625 - 2s - loss: 0.0876 - accuracy: 0.9722 - val_loss: 0.5235 - val_accuracy: 0.8384 - 2s/epoch - 4ms/step
# Epoch 10/30
# 625/625 - 4s - loss: 0.0761 - accuracy: 0.9753 - val_loss: 0.5712 - val_accuracy: 0.8359 - 4s/epoch - 7ms/step
# Epoch 11/30
# 625/625 - 3s - loss: 0.0664 - accuracy: 0.9803 - val_loss: 0.6198 - val_accuracy: 0.8341 - 3s/epoch - 4ms/step
# Epoch 12/30
# 625/625 - 3s - loss: 0.0580 - accuracy: 0.9825 - val_loss: 0.6724 - val_accuracy: 0.8307 - 3s/epoch - 6ms/step
# Epoch 13/30
# 625/625 - 6s - loss: 0.0505 - accuracy: 0.9854 - val_loss: 0.7157 - val_accuracy: 0.8237 - 6s/epoch - 10ms/step
# Epoch 14/30
# 625/625 - 6s - loss: 0.0448 - accuracy: 0.9871 - val_loss: 0.7642 - val_accuracy: 0.8237 - 6s/epoch - 10ms/step
# Epoch 15/30
# 625/625 - 3s - loss: 0.0397 - accuracy: 0.9890 - val_loss: 0.8235 - val_accuracy: 0.8232 - 3s/epoch - 4ms/step
# Epoch 16/30
# 625/625 - 3s - loss: 0.0349 - accuracy: 0.9905 - val_loss: 0.8706 - val_accuracy: 0.8193 - 3s/epoch - 5ms/step
# Epoch 17/30
# 625/625 - 3s - loss: 0.0310 - accuracy: 0.9916 - val_loss: 0.9202 - val_accuracy: 0.8171 - 3s/epoch - 6ms/step
# Epoch 18/30
# 625/625 - 3s - loss: 0.0280 - accuracy: 0.9929 - val_loss: 0.9871 - val_accuracy: 0.8149 - 3s/epoch - 5ms/step
# Epoch 19/30
# 625/625 - 3s - loss: 0.0250 - accuracy: 0.9939 - val_loss: 1.0479 - val_accuracy: 0.8131 - 3s/epoch - 4ms/step
# Epoch 20/30
# 625/625 - 3s - loss: 0.0229 - accuracy: 0.9937 - val_loss: 1.1383 - val_accuracy: 0.8143 - 3s/epoch - 4ms/step
# Epoch 21/30
# 625/625 - 4s - loss: 0.0205 - accuracy: 0.9940 - val_loss: 1.1569 - val_accuracy: 0.8082 - 4s/epoch - 6ms/step
# Epoch 22/30
# 625/625 - 3s - loss: 0.0181 - accuracy: 0.9947 - val_loss: 1.2420 - val_accuracy: 0.8074 - 3s/epoch - 4ms/step
# Epoch 23/30
# 625/625 - 3s - loss: 0.0151 - accuracy: 0.9959 - val_loss: 1.2770 - val_accuracy: 0.8047 - 3s/epoch - 4ms/step
# Epoch 24/30
# 625/625 - 3s - loss: 0.0146 - accuracy: 0.9960 - val_loss: 1.3355 - val_accuracy: 0.8071 - 3s/epoch - 4ms/step
# Epoch 25/30
# 625/625 - 3s - loss: 0.0130 - accuracy: 0.9966 - val_loss: 1.3960 - val_accuracy: 0.8053 - 3s/epoch - 5ms/step
# Epoch 26/30
# 625/625 - 3s - loss: 0.0114 - accuracy: 0.9969 - val_loss: 1.4797 - val_accuracy: 0.8025 - 3s/epoch - 5ms/step
# Epoch 27/30
# 625/625 - 3s - loss: 0.0097 - accuracy: 0.9975 - val_loss: 1.5892 - val_accuracy: 0.8044 - 3s/epoch - 4ms/step
# Epoch 28/30
# 625/625 - 3s - loss: 0.0104 - accuracy: 0.9973 - val_loss: 1.5873 - val_accuracy: 0.8030 - 3s/epoch - 4ms/step
# Epoch 29/30
# 625/625 - 3s - loss: 0.0080 - accuracy: 0.9979 - val_loss: 1.6485 - val_accuracy: 0.7989 - 3s/epoch - 4ms/step
# Epoch 30/30
# 625/625 - 4s - loss: 0.0079 - accuracy: 0.9981 - val_loss: 1.7105 - val_accuracy: 0.8010 - 4s/epoch - 6ms/step

# %%
import matplotlib.pyplot as plt

# Plot utility
def plot_graphs(history, string):
  plt.plot(history.history[string])
  plt.plot(history.history['val_'+string])
  plt.xlabel("Epochs")
  plt.ylabel(string)
  plt.legend([string, 'val_'+string])
  plt.show()

# Plot the accuracy and loss
plot_graphs(history, "accuracy")
plot_graphs(history, "loss")
